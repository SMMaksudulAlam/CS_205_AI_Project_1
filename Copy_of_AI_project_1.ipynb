# %% [markdown]
# <a href="https://colab.research.google.com/github/SMMaksudulAlam/CS_205_AI_Project_1/blob/main/Copy_of_AI_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
from queue import PriorityQueue
import time
import matplotlib.pyplot as plt

# %%
puzzle = 8
dim = int(math.sqrt(puzzle)) + 1
print(dim)
# Out:
# 3

# %%
goal_state = []
co_ordinates = {}
for i in range(dim):
  temp = []
  for j in range(dim):
    val = i*dim+(j+1)
    temp.append(val)
    co_ord = [i, j]
    co_ordinates[val] = co_ord
  goal_state.append(temp)

last_val = goal_state[-1][-1]
goal_state[-1][-1] = 0
temp_co_ord = co_ordinates[last_val]
del co_ordinates[last_val]
co_ordinates[0] = temp_co_ord
print(last_val)
print(goal_state)
print(co_ordinates)
# Out:
# 9
# [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
# {1: [0, 0], 2: [0, 1], 3: [0, 2], 4: [1, 0], 5: [1, 1], 6: [1, 2], 7: [2, 0], 8: [2, 1], 0: [2, 2]}

# %%
def manhattan_distance(state):
  m_dist = 0
  for i in range(dim):
    for j in range(dim):
      val = state[i][j]
      if(val == 0):
        continue
      goal_co_ord = co_ordinates[val]
      i_goal = goal_co_ord[0]
      j_goal = goal_co_ord[1]
      m_dist += abs(i_goal - i) + abs(j_goal - j)
  return m_dist

# %%
state = [[7, 2, 4], [5, 0, 6], [8, 3, 1]]
dist = manhattan_distance(state)
print(dist)
# Out:
# 14

# %%
def misplaced_tile(state):
  m_tile = 0
  for i in range(dim):
    for j in range(dim):
      val = goal_state[i][j]
      if(val == 0):
        continue
      if(val != state[i][j]):
        m_tile += 1
  return m_tile

# %%
class Node:
  def __init__(self, state, parent=None, g=0):
    self.state = state
    self.parent = parent
    self.g = g
    self.h = 0
    self.total_cost = 0
    
  def __lt__(self, other_node):
        return self.total_cost < other_node.total_cost

# %%
def expand(node):
  state = node.state
  expanded_nodes = []
  blank_i = dim - 1
  blank_j = dim - 1

  for i in range(dim):
    for j in range(dim):
      if(state[i][j] == 0):
        blank_i = i
        blank_j = j
        break
  if(blank_i > 0):
    child = []
    for lst in state:
      child.append(lst[:])
    val = state[blank_i - 1][blank_j]
    child[blank_i][blank_j] = val
    child[blank_i - 1][blank_j] = 0
    child_node = Node(child, state, node.g+1)
    expanded_nodes.append(child_node)

  if(blank_i < dim - 1):
    child = []
    for lst in state:
      child.append(lst[:])
    val = state[blank_i + 1][blank_j]
    child[blank_i][blank_j] = val
    child[blank_i + 1][blank_j] = 0
    child_node = Node(child, state, node.g+1)
    expanded_nodes.append(child_node)

  if(blank_j > 0):
    child = []
    for lst in state:
      child.append(lst[:])
    val = state[blank_i][blank_j - 1]
    child[blank_i][blank_j] = val
    child[blank_i][blank_j - 1] = 0
    child_node = Node(child, state, node.g+1)
    expanded_nodes.append(child_node)

  if(blank_j < dim - 1):
    child = []
    for lst in state:
      child.append(lst[:])
    val = state[blank_i][blank_j + 1]
    child[blank_i][blank_j] = val
    child[blank_i][blank_j + 1] = 0
    child_node = Node(child, state, node.g+1)
    expanded_nodes.append(child_node)

  return expanded_nodes

# %%
def uniform_cost_search(node):
  q = PriorityQueue()
  q.put(node)
  is_visited = set()
  number_of_expansion = 0
  s_time = time.process_time()
  max_queue_size = 0
  while (q.empty() == False):
    nde = q.get()
    print(nde.state, 'is the best sub-puzzle to be solved with g(n): '+str(nde.g))
    if(misplaced_tile(nde.state) == 0):
      e_time = time.process_time()
      print("reached the goal state!")
      print("the number of expansion required: "+ str(number_of_expansion))
      print("maximum queue size: "+ str(max_queue_size))
      print("time required: "+str(e_time - s_time))
      return nde
    expanded_nodes = expand(nde)
    number_of_expansion += 1
    tple = tuple(map(tuple, nde.state))
    is_visited.add(tple)

    for child_node in expanded_nodes:
      child_tuple = tuple(map(tuple, child_node.state))
      if(child_tuple not in is_visited):
        child_node.total_cost = child_node.g
        q.put(child_node)
    if(q.qsize() > max_queue_size):
      max_queue_size = q.qsize()
  print("queue is empty!")
  return None

# %%
def a_star_with_MD(node):
  q = PriorityQueue()
  q.put(node)
  is_visited = set()
  number_of_expansion = 0
  s_time = time.process_time()
  max_queue_size = 0
  while (q.empty() == False):
    nde = q.get()
    print(nde.state, 'is the best sub-puzzle to be solved with g(n): '+str(nde.g)+ ' and h(n): '+str(nde.h))
    if(misplaced_tile(nde.state) == 0):
      e_time = time.process_time()
      print("reached the goal state!")
      print("the number of expansion required: "+ str(number_of_expansion))
      print("maximum queue size: "+ str(max_queue_size))
      print("time required: "+str(e_time - s_time))
      return nde
    expanded_nodes = expand(nde)
    number_of_expansion += 1
    tple = tuple(map(tuple, nde.state))
    is_visited.add(tple)

    for child_node in expanded_nodes:
      child_tuple = tuple(map(tuple, child_node.state))
      if(child_tuple not in is_visited):
        child_node.h = manhattan_distance(child_node.state)
        child_node.total_cost = child_node.g + child_node.h
        q.put(child_node)
    if(q.qsize() > max_queue_size):
      max_queue_size = q.qsize()
  print("queue is empty!")
  return None

# %%
def a_star_with_MT(node):
  q = PriorityQueue()
  q.put(node)
  is_visited = set()
  number_of_expansion = 0
  s_time = time.process_time()
  max_queue_size = 0
  while (q.empty() == False):
    nde = q.get()
    print(nde.state, 'is the best sub-puzzle to be solved with g(n): '+str(nde.g)+ ' and h(n): '+str(nde.h))
    if(misplaced_tile(nde.state) == 0):
      e_time = time.process_time()
      print("reached the goal state!")
      print("the number of expansion required: "+ str(number_of_expansion))
      print("maximum queue size: "+ str(max_queue_size))
      print("time required: "+str(e_time - s_time))
      return nde
    expanded_nodes = expand(nde)
    number_of_expansion += 1
    tple = tuple(map(tuple, nde.state))
    is_visited.add(tple)

    for child_node in expanded_nodes:
      child_tuple = tuple(map(tuple, child_node.state))
      if(child_tuple not in is_visited):
        child_node.h = misplaced_tile(child_node.state)
        child_node.total_cost = child_node.g + child_node.h
        q.put(child_node)
    if(q.qsize() > max_queue_size):
      max_queue_size = q.qsize()
  print("queue is empty!")
  return None

# %%
def main():
  init_state = [[0, 7, 2], [4, 6, 1], [3, 5, 8]]
  print("Welcome to the Eight Puzzle Solver!")
  mode = input("Enter 1 to use the default puzzle or 2 to create a manual one! ")
  state = []
  if(mode == '1'):
    state = init_state
  if(mode == '2'):
    r_str = input('Enter the 1st row in C1 C2 C3 format: ').split()
    r = []
    for s in r_str:
      r.append(int(s))
    state.append(r)

    r_str = input('Enter the 2nd row in C1 C2 C3 format: ').split()
    r = []
    for s in r_str:
      r.append(int(s))
    state.append(r)

    r_str = input('Enter the 3rd row in C1 C2 C3 format: ').split()
    r = []
    for s in r_str:
      r.append(int(s))
    state.append(r)    

  node = Node(state)
  print("Please select any of the following algorithms to solve the puzzle!")
  print('1. Uniform Cost Search!')
  print('2. A* Search with Manhattan Distance Heuristic!')
  print('3. A* Search with Misplaced Tile Heuristic!')
  algo = input("Enter a number to select the corresponding algorithm! ")

  if(algo == '1'):
    uniform_cost_search(node)
  if(algo == '2'):
    a_star_with_MD(node)
  if(algo == '3'):
    a_star_with_MT(node)

# %%
if __name__=="__main__":
  main()
# Out:
# Streaming output truncated to the last 5000 lines.
# [[6, 4, 2], [3, 8, 0], [7, 5, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 4, 6], [3, 1, 7], [5, 2, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 0, 3], [5, 2, 1], [4, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 6, 4], [3, 0, 1], [5, 7, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 1, 8], [3, 4, 6], [5, 0, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 6, 2], [8, 3, 1], [5, 4, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 3, 7], [0, 4, 1], [6, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 8, 2], [7, 0, 3], [4, 1, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 2, 5], [4, 1, 8], [6, 3, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 8, 4], [3, 7, 1], [0, 6, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 3, 7], [4, 0, 1], [6, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 7, 6], [8, 2, 5], [4, 0, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 8, 4], [7, 6, 1], [3, 5, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 6, 4], [3, 7, 0], [5, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 2], [3, 7, 0], [5, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 7, 0], [3, 4, 6], [5, 2, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 7, 5], [0, 1, 6], [3, 2, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 5, 1], [6, 3, 4], [0, 7, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 3, 2], [7, 1, 8], [4, 6, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 6, 3], [1, 2, 0], [5, 4, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 1], [8, 3, 4], [6, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 2], [6, 1, 8], [0, 7, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 5, 6], [7, 8, 0], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 7, 6], [0, 5, 1], [4, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 0, 6], [7, 8, 2], [3, 4, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 7], [8, 2, 0], [3, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 5, 0], [7, 8, 6], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 3, 7], [4, 6, 2], [0, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 2, 3], [4, 1, 7], [5, 8, 6]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[1, 4, 7], [8, 2, 6], [3, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 4, 7], [0, 1, 2], [3, 8, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 3, 2], [8, 4, 5], [0, 6, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 2, 8], [4, 6, 1], [5, 3, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 7, 8], [4, 5, 2], [3, 0, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 0, 6], [8, 5, 2], [1, 4, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 8], [0, 1, 6], [3, 5, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 6, 2], [8, 4, 5], [1, 3, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 1, 7], [5, 2, 0], [3, 8, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 1, 0], [5, 4, 3], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 2, 8], [0, 3, 4], [1, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 0], [5, 6, 7], [3, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 1, 7], [5, 2, 6], [3, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 1, 3], [5, 4, 0], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[1, 6, 4], [2, 7, 8], [3, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[8, 7, 2], [4, 1, 0], [6, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 8], [0, 7, 1], [3, 5, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 1, 3], [5, 4, 6], [7, 8, 0]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[6, 2, 1], [5, 3, 7], [8, 0, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 5, 0], [1, 2, 6], [4, 8, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 4, 1], [8, 0, 7], [3, 2, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 2, 5], [8, 6, 0], [1, 4, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 5, 4], [6, 7, 0], [3, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 5, 6], [2, 3, 0], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 4, 5], [8, 0, 7], [3, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 2, 5], [8, 0, 6], [1, 4, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 6, 1], [3, 4, 0], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 5, 0], [2, 3, 6], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 2, 6], [3, 8, 1], [7, 4, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 4, 2], [6, 7, 3], [5, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 8, 7], [5, 3, 2], [1, 6, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 7, 6], [2, 8, 5], [1, 3, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 5, 2], [1, 6, 8], [4, 3, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 7, 3], [4, 8, 2], [1, 6, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 7], [4, 1, 8], [3, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 1], [5, 0, 7], [4, 8, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 7, 6], [4, 2, 0], [8, 1, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 7, 0], [6, 4, 1], [5, 2, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[8, 4, 2], [7, 3, 5], [6, 1, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 1], [0, 5, 7], [4, 8, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[3, 7, 0], [4, 2, 6], [8, 1, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[8, 0, 4], [7, 5, 2], [6, 3, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 0, 2], [7, 5, 8], [1, 3, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 1], [4, 5, 7], [0, 8, 3]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[4, 6, 5], [0, 1, 7], [3, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 6, 1], [7, 2, 8], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 0], [7, 5, 8], [1, 3, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 4, 7], [5, 6, 1], [0, 2, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 6, 5], [4, 1, 7], [3, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 0], [5, 7, 1], [4, 8, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 7, 1], [2, 3, 5], [0, 6, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 6, 4], [8, 0, 2], [3, 1, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 1, 6], [4, 7, 2], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 8], [3, 5, 4], [1, 6, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[8, 4, 7], [6, 5, 2], [3, 0, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[5, 7, 0], [4, 3, 6], [8, 1, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 1, 6], [4, 7, 2], [5, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 8, 7], [1, 0, 3], [6, 5, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 3, 2], [6, 5, 1], [0, 8, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 6, 4], [3, 8, 2], [0, 1, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 4, 5], [2, 8, 7], [0, 3, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 8, 7], [1, 5, 3], [6, 0, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 1, 7], [6, 5, 0], [2, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 7, 2], [1, 5, 0], [4, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 3, 5], [4, 7, 0], [6, 8, 2]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[1, 4, 0], [6, 7, 5], [3, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 5, 7], [1, 0, 2], [4, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 5, 0], [2, 7, 4], [3, 8, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 7, 1], [4, 8, 2], [3, 0, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 0, 6], [2, 1, 5], [7, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 7, 1], [2, 4, 8], [3, 5, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 1, 0], [3, 6, 7], [5, 4, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 1], [0, 8, 5], [4, 7, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 7], [8, 3, 6], [0, 5, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 6, 3], [4, 0, 1], [5, 2, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 2, 3], [6, 7, 1], [8, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 3, 4], [2, 7, 0], [5, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 4, 2], [6, 7, 3], [8, 5, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 5, 6], [4, 2, 8], [1, 0, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 6, 7], [4, 3, 1], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 5, 7], [2, 4, 0], [3, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 8, 1], [4, 3, 5], [6, 0, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 1], [7, 8, 4], [5, 0, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 0, 8], [4, 6, 5], [3, 1, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 7, 1], [2, 6, 8], [3, 4, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 2, 6], [5, 3, 0], [8, 4, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 6], [8, 3, 5], [0, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 2, 5], [6, 7, 0], [4, 8, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[2, 1, 7], [3, 4, 0], [5, 8, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 4, 7], [5, 3, 6], [1, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 4, 2], [6, 0, 8], [3, 1, 7]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 1, 8], [4, 5, 7], [3, 6, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 3, 7], [5, 0, 6], [1, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 6, 1], [7, 0, 8], [3, 5, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 4, 2], [0, 7, 1], [6, 8, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 5], [0, 1, 8], [6, 3, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 3, 7], [0, 5, 6], [1, 8, 2]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[2, 6, 1], [7, 5, 8], [3, 0, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 2, 5], [6, 3, 8], [7, 4, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 2, 8], [3, 5, 4], [0, 1, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 3, 7], [4, 5, 6], [1, 8, 2]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[2, 1, 0], [4, 5, 8], [3, 6, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 1, 0], [4, 7, 2], [3, 8, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 2, 8], [0, 6, 3], [5, 4, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 8], [5, 3, 0], [6, 7, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[5, 7, 6], [4, 2, 0], [8, 3, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 7, 2], [6, 3, 4], [5, 1, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 0, 6], [4, 7, 2], [8, 3, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 5, 2], [8, 3, 1], [0, 4, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 7, 0], [4, 2, 6], [8, 3, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 3, 6], [5, 2, 1], [0, 4, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 7, 2], [5, 8, 1], [4, 6, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 7, 1], [6, 3, 5], [0, 4, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 7, 1], [2, 6, 5], [4, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 7, 2], [5, 3, 4], [0, 1, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 3], [7, 8, 1], [5, 4, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 8, 2], [7, 0, 3], [5, 4, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 2, 1], [4, 6, 8], [7, 0, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 7, 1], [5, 0, 2], [8, 3, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 6, 7], [8, 0, 1], [3, 2, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 2, 8], [0, 7, 4], [5, 1, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 1, 8], [3, 2, 7], [0, 6, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 7, 1], [0, 5, 2], [8, 3, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 5], [3, 1, 8], [7, 6, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 2, 8], [0, 3, 5], [1, 6, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 8, 0], [4, 7, 2], [6, 3, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 7, 1], [4, 5, 2], [8, 3, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 2, 0], [3, 1, 5], [7, 6, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 6, 2], [7, 8, 3], [4, 1, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 2, 3], [5, 4, 7], [6, 0, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[1, 5, 6], [7, 0, 2], [3, 8, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 3, 7], [4, 0, 6], [8, 1, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 8, 3], [4, 1, 2], [0, 5, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 2, 3], [5, 4, 7], [6, 8, 0]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[2, 8, 0], [7, 5, 6], [4, 1, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 1, 2], [7, 4, 3], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[8, 0, 2], [4, 7, 1], [6, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 5, 1], [6, 0, 7], [2, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 4, 6], [8, 2, 1], [3, 5, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 0, 2], [7, 4, 3], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[8, 2, 0], [4, 7, 1], [6, 3, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 1, 4], [3, 7, 6], [5, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 5], [4, 0, 8], [3, 7, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 2, 0], [7, 4, 3], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 5, 8], [4, 2, 0], [6, 3, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 6], [4, 3, 8], [1, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 6, 1], [2, 3, 7], [5, 4, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 2, 3], [7, 4, 0], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 2, 1], [5, 8, 0], [6, 3, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 8], [3, 1, 5], [7, 4, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 3, 6], [7, 4, 2], [5, 1, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 1, 6], [5, 3, 8], [0, 2, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 7, 6], [3, 1, 8], [5, 2, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 4, 0], [3, 8, 2], [7, 6, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 5, 2], [4, 7, 0], [8, 1, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 0, 1], [6, 2, 8], [7, 5, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 3, 2], [1, 8, 6], [4, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 8], [2, 3, 7], [6, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 1, 6], [7, 3, 8], [5, 2, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 4, 2], [8, 6, 1], [7, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 3, 2], [1, 0, 6], [4, 8, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 0, 8], [2, 4, 7], [6, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 0, 6], [7, 3, 8], [5, 2, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 8, 0], [4, 5, 2], [1, 6, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 6, 2], [4, 5, 1], [7, 8, 3]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[7, 2, 3], [0, 4, 1], [5, 8, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 2, 5], [4, 8, 3], [1, 6, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 7, 2], [3, 1, 0], [5, 8, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 8, 2], [4, 6, 5], [1, 0, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 3], [4, 0, 1], [5, 8, 6]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[2, 3, 0], [4, 5, 1], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[4, 3, 1], [6, 5, 7], [0, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 8, 6], [4, 1, 0], [3, 7, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 6, 5], [4, 1, 0], [3, 7, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 0, 3], [4, 5, 1], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 21 and h(n): 3
# [[0, 7, 3], [4, 1, 8], [5, 2, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 0, 4], [3, 2, 1], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 0, 5], [1, 6, 7], [3, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 2, 3], [4, 5, 1], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 22 and h(n): 2
# [[0, 6, 4], [7, 1, 8], [3, 2, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 4], [3, 0, 1], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 7, 3], [5, 0, 2], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 1, 4], [7, 3, 6], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 4], [3, 1, 5], [0, 8, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 4], [3, 5, 1], [7, 0, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[6, 7, 3], [0, 5, 2], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[0, 1, 4], [6, 7, 8], [3, 2, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 2, 6], [7, 5, 3], [8, 4, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 4], [3, 5, 1], [7, 8, 0]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[6, 7, 3], [4, 5, 2], [0, 8, 1]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[1, 0, 4], [6, 7, 8], [3, 2, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 5, 2], [7, 3, 6], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 3, 0], [4, 6, 1], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 6, 4], [0, 3, 1], [5, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 4, 6], [3, 2, 5], [8, 1, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 3, 1], [5, 7, 0], [6, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 0, 3], [4, 6, 1], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 0, 1], [6, 3, 2], [5, 8, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 8, 5], [3, 6, 7], [0, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 1, 6], [5, 3, 4], [8, 2, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 2, 3], [4, 6, 1], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[0, 1, 2], [6, 5, 8], [7, 3, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 1, 5], [6, 2, 0], [7, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 4, 2], [8, 7, 1], [6, 5, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 6, 5], [3, 0, 7], [8, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 0, 2], [6, 5, 8], [7, 3, 4]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[6, 0, 8], [1, 2, 4], [7, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 7, 0], [5, 4, 8], [3, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 4, 5], [0, 6, 2], [3, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 2, 0], [6, 5, 8], [7, 3, 4]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[6, 4, 7], [5, 1, 8], [3, 2, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 3, 7], [4, 1, 8], [5, 0, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 8, 2], [0, 3, 1], [7, 6, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 7], [3, 2, 0], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 3, 7], [0, 5, 2], [1, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 8], [5, 4, 6], [0, 3, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 8, 2], [4, 3, 1], [7, 6, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 8, 5], [4, 3, 7], [6, 0, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 3, 7], [4, 5, 2], [1, 6, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 1, 7], [0, 5, 8], [2, 3, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 2, 8], [7, 4, 6], [5, 3, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 7, 6], [3, 1, 8], [2, 4, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 4, 7], [6, 3, 2], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 1, 7], [4, 5, 8], [2, 3, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 2, 8], [6, 5, 3], [0, 7, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 8, 2], [5, 3, 6], [4, 0, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 7], [6, 3, 2], [5, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 0, 7], [4, 5, 8], [2, 3, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 2, 8], [6, 5, 3], [7, 0, 1]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 0, 2], [5, 8, 6], [4, 3, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 6, 2], [5, 8, 4], [7, 0, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 5], [4, 0, 3], [6, 1, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 7, 6], [8, 0, 5], [1, 3, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 2, 0], [5, 8, 6], [4, 3, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 6, 7], [5, 2, 8], [4, 0, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 3, 2], [0, 5, 8], [1, 4, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 6], [8, 5, 0], [1, 3, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 6, 7], [5, 3, 0], [2, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 2, 8], [7, 1, 4], [5, 0, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 1, 4], [0, 7, 3], [5, 8, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 0], [8, 5, 6], [1, 3, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 3, 2], [5, 0, 4], [8, 7, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 6, 2], [5, 0, 1], [3, 7, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[8, 6, 7], [4, 2, 5], [3, 0, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 3, 4], [6, 0, 7], [5, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 3, 2], [0, 5, 4], [8, 7, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 6, 7], [8, 2, 1], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 6, 7], [3, 4, 5], [8, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 3, 2], [5, 4, 8], [6, 1, 7]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 7, 2], [0, 8, 6], [5, 4, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 1, 5], [3, 0, 2], [4, 6, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 7, 6], [3, 5, 8], [1, 0, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 1, 5], [6, 8, 2], [0, 3, 7]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 7, 2], [3, 0, 8], [5, 4, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 7, 5], [4, 6, 2], [0, 3, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 8], [5, 4, 3], [7, 1, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 4, 2], [3, 0, 1], [8, 6, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 7, 1], [5, 3, 2], [8, 6, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 7, 1], [6, 0, 5], [3, 2, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 4, 7], [5, 1, 8], [6, 2, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 5, 1], [4, 0, 2], [6, 8, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 7, 2], [0, 4, 8], [6, 5, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 2, 0], [6, 4, 1], [5, 8, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 3, 2], [4, 1, 6], [8, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 0, 4], [6, 8, 2], [3, 7, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 5], [0, 8, 1], [6, 7, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 4, 8], [2, 7, 5], [3, 1, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 1, 0], [3, 7, 5], [8, 2, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 2, 6], [5, 0, 1], [7, 3, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 2, 5], [4, 8, 1], [6, 7, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 8, 2], [3, 1, 6], [5, 0, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 4, 8], [1, 2, 7], [3, 5, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 8, 2], [0, 3, 6], [5, 1, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 7], [8, 1, 6], [3, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 1, 6], [4, 0, 3], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 4, 8], [0, 2, 7], [3, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 8, 2], [4, 3, 6], [5, 1, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 8, 4], [0, 1, 2], [7, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 1, 6], [4, 5, 3], [7, 0, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 6, 3], [2, 0, 7], [5, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 8, 4], [1, 3, 2], [7, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 1, 5], [6, 0, 7], [3, 2, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 1, 6], [4, 5, 3], [7, 8, 0]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[4, 7, 3], [1, 2, 8], [5, 0, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 7, 6], [4, 1, 8], [3, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 8, 0], [7, 1, 2], [3, 4, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[8, 1, 6], [7, 0, 2], [4, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 4, 6], [5, 7, 1], [3, 2, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 1, 8], [2, 5, 6], [0, 4, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 6, 8], [7, 1, 2], [3, 4, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 1, 8], [7, 4, 2], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 7, 8], [2, 3, 6], [4, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 8, 7], [3, 0, 1], [5, 6, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 1, 7], [4, 5, 8], [6, 2, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 1, 8], [0, 4, 2], [7, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 6, 4], [7, 1, 8], [3, 2, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 3, 1], [7, 8, 4], [0, 5, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 4, 2], [8, 7, 6], [1, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 0, 4], [2, 5, 7], [3, 8, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[1, 2, 8], [4, 7, 0], [6, 5, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[2, 3, 1], [0, 8, 4], [7, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 7, 2], [3, 5, 1], [6, 8, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 8], [3, 4, 1], [7, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 1, 7], [0, 3, 6], [5, 4, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 0, 7], [3, 1, 6], [5, 4, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 0, 1], [7, 5, 4], [2, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 4], [1, 5, 0], [7, 3, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[0, 7, 6], [3, 1, 8], [5, 2, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 2, 7], [3, 1, 6], [5, 4, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 4, 0], [3, 5, 2], [6, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 5, 4], [3, 0, 7], [8, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 1, 6], [7, 3, 8], [5, 2, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 0, 4], [1, 8, 2], [7, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 6, 2], [5, 4, 8], [7, 3, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 2, 3], [1, 4, 7], [5, 6, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[8, 4, 2], [0, 3, 6], [5, 7, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 5], [0, 7, 8], [3, 1, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 7], [5, 2, 6], [1, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 8, 0], [6, 7, 5], [3, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 8, 1], [4, 2, 0], [3, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 2], [8, 3, 1], [5, 6, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 4, 7], [5, 2, 6], [1, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 3, 1], [4, 0, 7], [5, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 4, 1], [0, 2, 5], [6, 8, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 5, 6], [0, 4, 1], [3, 8, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 1, 0], [2, 5, 7], [3, 8, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 4], [0, 7, 1], [5, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 5, 2], [3, 8, 6], [4, 0, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 1], [3, 8, 5], [0, 6, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 8, 6], [1, 2, 5], [0, 4, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 6, 0], [2, 1, 8], [3, 7, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 0, 7], [8, 5, 2], [1, 6, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 2], [8, 0, 1], [5, 7, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 4, 2], [6, 3, 1], [0, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 4, 2], [5, 8, 1], [0, 7, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 1, 8], [4, 5, 7], [0, 3, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 1, 6], [7, 8, 3], [4, 5, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 7], [3, 8, 0], [5, 1, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 2], [5, 8, 1], [7, 0, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 4, 2], [7, 3, 1], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 2, 5], [7, 4, 0], [6, 8, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 0, 2], [6, 5, 4], [1, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 2], [5, 0, 1], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 0, 8], [4, 1, 7], [3, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 3], [4, 6, 8], [5, 0, 1]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 2, 0], [6, 5, 4], [1, 3, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 4, 2], [0, 5, 1], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[1, 2, 5], [4, 7, 8], [6, 0, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[6, 2, 7], [0, 8, 4], [3, 5, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 4, 2], [1, 3, 7], [0, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 2, 3], [4, 8, 6], [5, 0, 7]] is the best sub-puzzle to be solved with g(n): 21 and h(n): 3
# [[0, 8, 6], [7, 2, 5], [4, 3, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 8, 1], [7, 3, 5], [0, 4, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 6, 7], [1, 2, 8], [4, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 0, 3], [4, 2, 6], [5, 8, 7]] is the best sub-puzzle to be solved with g(n): 21 and h(n): 3
# [[3, 2, 0], [4, 5, 1], [7, 6, 8]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[2, 8, 1], [0, 3, 5], [7, 4, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 3, 2], [4, 0, 5], [1, 8, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 2, 0], [4, 6, 3], [5, 8, 7]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[6, 7, 0], [4, 1, 2], [3, 8, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 3, 4], [0, 6, 2], [5, 7, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 3, 2], [4, 5, 0], [1, 8, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 1, 6], [3, 2, 8], [0, 7, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 8, 6], [7, 2, 1], [4, 3, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 2, 7], [8, 1, 6], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 5, 6], [4, 8, 1], [3, 0, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 1, 6], [3, 2, 8], [7, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 3, 4], [6, 7, 2], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 5], [7, 0, 6], [3, 2, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 1, 6], [5, 7, 3], [0, 4, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 1, 2], [6, 0, 4], [3, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 3, 4], [6, 7, 2], [5, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[8, 3, 7], [4, 2, 0], [5, 1, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 1], [0, 8, 3], [4, 6, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 1, 2], [6, 5, 4], [3, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 0, 1], [5, 4, 2], [6, 8, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[8, 3, 7], [4, 2, 6], [5, 1, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 4], [3, 5, 1], [7, 8, 0]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[7, 1, 2], [6, 5, 4], [3, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 7, 2], [0, 3, 6], [8, 4, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 1], [8, 6, 3], [4, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[5, 6, 2], [7, 0, 8], [4, 3, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 3, 4], [2, 7, 0], [5, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 2], [0, 6, 8], [7, 1, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[8, 3, 7], [4, 1, 2], [5, 0, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 1], [6, 8, 5], [2, 3, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 0, 2], [6, 4, 8], [7, 1, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 7, 2], [3, 1, 8], [4, 6, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 3, 2], [1, 5, 0], [4, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 3, 4], [2, 6, 7], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 2, 0], [6, 4, 8], [7, 1, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 2, 5], [7, 6, 1], [3, 8, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 0, 4], [3, 2, 7], [6, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 3, 4], [2, 6, 7], [5, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 8, 6], [3, 1, 2], [0, 5, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 8, 6], [7, 3, 2], [5, 1, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 2, 4], [3, 0, 7], [6, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 4, 1], [3, 5, 0], [8, 2, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 1], [2, 6, 0], [5, 8, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 2, 1], [5, 8, 0], [6, 4, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 2], [5, 1, 7], [8, 6, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 0, 1], [5, 2, 6], [8, 3, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 8, 2], [0, 7, 6], [4, 5, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 8, 1], [7, 3, 5], [0, 4, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 2, 6], [5, 3, 8], [1, 0, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 4, 2], [0, 5, 7], [3, 1, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 8, 2], [4, 7, 6], [0, 5, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 1, 2], [0, 3, 6], [5, 7, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[5, 7, 1], [3, 0, 6], [4, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 7, 6], [8, 4, 2], [3, 5, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 1, 2], [3, 7, 6], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 1, 2], [4, 3, 6], [5, 7, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 3, 1], [7, 0, 6], [5, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 2, 8], [5, 1, 0], [6, 3, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 1, 6], [7, 0, 8], [5, 3, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 0, 2], [4, 3, 6], [5, 7, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[1, 3, 6], [2, 0, 5], [7, 4, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 8, 6], [1, 0, 5], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 5, 1], [3, 6, 8], [7, 0, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 2, 0], [4, 3, 6], [5, 7, 8]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[1, 3, 6], [2, 5, 0], [7, 4, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 8, 6], [1, 5, 0], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 2, 8], [0, 3, 4], [5, 1, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 4, 2], [1, 6, 8], [3, 7, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 3, 0], [2, 5, 6], [7, 4, 8]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[7, 8, 0], [1, 5, 6], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 4, 5], [1, 7, 2], [6, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 8], [3, 1, 4], [5, 0, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 0, 3], [2, 5, 6], [7, 4, 8]] is the best sub-puzzle to be solved with g(n): 21 and h(n): 3
# [[7, 2, 1], [6, 4, 0], [5, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 5], [0, 7, 2], [6, 3, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 5, 0], [1, 7, 2], [6, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 0, 1], [3, 7, 5], [6, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 8], [0, 1, 3], [4, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 6, 4], [1, 2, 8], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 1, 3], [7, 6, 4], [5, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 1, 5], [4, 0, 7], [3, 8, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 3, 7], [5, 1, 2], [8, 6, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 4, 1], [5, 8, 0], [7, 2, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 1, 3], [7, 6, 4], [5, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 5, 1], [8, 0, 7], [6, 3, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 0, 3], [7, 1, 4], [5, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 1], [5, 8, 6], [7, 2, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 4, 3], [7, 6, 2], [0, 5, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 0, 1], [8, 5, 7], [6, 3, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 2, 3], [7, 1, 4], [5, 6, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 0, 5], [3, 6, 2], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 4, 3], [0, 6, 2], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[0, 4, 6], [2, 1, 8], [3, 7, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 7, 6], [1, 4, 0], [5, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 7, 2], [4, 8, 6], [5, 0, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 2, 1], [6, 8, 0], [5, 3, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 6, 8], [2, 0, 4], [7, 3, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 2, 1], [0, 6, 8], [5, 3, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 0, 8], [4, 2, 1], [5, 6, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 5, 2], [6, 8, 4], [0, 3, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 6, 4], [2, 7, 0], [3, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 2, 1], [4, 6, 8], [5, 3, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 7, 5], [1, 3, 0], [6, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 8, 2], [0, 4, 1], [7, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 8, 1], [4, 3, 6], [7, 0, 5]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[5, 2, 0], [4, 1, 7], [6, 3, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 2, 8], [1, 5, 3], [0, 4, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 0, 4], [7, 6, 5], [3, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 7, 6], [2, 4, 1], [3, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 0, 1], [3, 8, 6], [5, 2, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 7], [0, 1, 8], [3, 6, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 8], [5, 0, 6], [1, 7, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 4, 3], [5, 2, 1], [6, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 4, 7], [5, 6, 2], [3, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# ...
# [[7, 3, 2], [1, 4, 8], [0, 6, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 0, 2], [4, 8, 5], [3, 7, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 3, 1], [7, 5, 6], [8, 4, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 2, 1], [0, 7, 8], [6, 4, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 1], [6, 2, 8], [0, 5, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 5, 2], [3, 1, 8], [0, 7, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 3, 7], [5, 0, 2], [1, 6, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 2, 0], [4, 8, 5], [3, 7, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 4, 5], [7, 1, 0], [3, 8, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 3, 6], [5, 7, 2], [4, 1, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 4, 2], [0, 5, 8], [1, 3, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 8, 4], [7, 0, 6], [3, 2, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 7, 2], [4, 8, 6], [5, 1, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 3, 0], [5, 2, 4], [7, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 8, 7], [4, 3, 6], [5, 2, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 4, 1], [7, 2, 8], [5, 6, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 2, 8], [4, 6, 3], [0, 1, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 6, 1], [5, 7, 8], [4, 3, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 0, 1], [6, 5, 2], [3, 7, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 1], [2, 8, 0], [7, 6, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 7, 0], [3, 5, 6], [4, 8, 2]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[6, 3, 2], [4, 0, 8], [7, 1, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 0, 1], [5, 8, 6], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 5, 6], [7, 3, 4], [8, 1, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 1, 0], [7, 2, 3], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 3, 0], [4, 1, 2], [6, 8, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 7, 2], [1, 3, 0], [5, 8, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 0, 1], [7, 5, 3], [6, 4, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 0, 6], [2, 7, 3], [5, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 0, 4], [3, 2, 6], [1, 5, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 1, 3], [7, 2, 0], [6, 5, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 5, 7], [4, 2, 6], [3, 0, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 7, 6], [3, 1, 8], [2, 5, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 4, 5], [7, 2, 1], [6, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 4, 8], [6, 1, 5], [3, 2, 7]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 1, 7], [0, 4, 5], [3, 8, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 4, 6], [2, 8, 7], [5, 1, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 5, 7], [4, 2, 6], [3, 8, 0]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[7, 3, 2], [5, 0, 8], [6, 1, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 4, 5], [6, 2, 8], [3, 1, 7]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 4, 2], [5, 7, 1], [8, 3, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 2, 1], [4, 0, 3], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[6, 0, 4], [2, 1, 8], [7, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 5], [1, 0, 4], [3, 8, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 3, 2], [0, 5, 8], [6, 1, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 6, 8], [4, 7, 2], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 7, 0], [6, 8, 2], [1, 4, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 3, 2], [4, 6, 0], [1, 5, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 5, 1], [2, 0, 3], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 6, 7], [2, 4, 0], [5, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 6, 3], [7, 4, 1], [5, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 3, 7], [5, 4, 2], [8, 1, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[7, 5, 2], [3, 4, 6], [1, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 3, 1], [6, 4, 5], [7, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 0, 1], [2, 5, 3], [7, 8, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[0, 2, 6], [3, 1, 7], [5, 8, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 6, 2], [7, 4, 3], [8, 5, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 8, 0], [4, 6, 5], [3, 2, 7]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 2, 0], [6, 4, 7], [3, 5, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 5, 2], [6, 1, 0], [4, 8, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 5, 2], [0, 6, 1], [4, 8, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 6], [0, 5, 8], [1, 2, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 0, 8], [4, 1, 2], [6, 5, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 0], [5, 4, 6], [8, 1, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 4, 7], [8, 6, 2], [0, 3, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 2, 8], [3, 1, 6], [0, 7, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 6, 2], [3, 7, 8], [4, 0, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 7, 6], [4, 5, 8], [1, 2, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 0, 1], [3, 4, 6], [8, 2, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 3, 1], [7, 5, 0], [4, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 5, 0], [7, 2, 1], [6, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 1, 8], [7, 5, 6], [4, 3, 2]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[4, 0, 7], [3, 5, 6], [2, 8, 1]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[4, 5, 6], [2, 7, 0], [3, 8, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 5, 1], [0, 3, 6], [2, 7, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 5, 2], [7, 0, 1], [3, 6, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 2, 1], [4, 7, 8], [6, 5, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 2, 1], [7, 5, 8], [6, 3, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 0, 1], [3, 8, 6], [2, 4, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 1, 8], [7, 6, 5], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 5, 1], [4, 3, 6], [2, 7, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 7, 1], [0, 5, 4], [8, 2, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 1, 2], [0, 3, 8], [7, 5, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 1, 8], [4, 5, 2], [6, 3, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[0, 7, 2], [5, 8, 1], [4, 6, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 0, 8], [7, 6, 5], [4, 2, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 0, 7], [5, 2, 6], [4, 1, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 2, 5], [7, 6, 0], [3, 8, 4]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[0, 1, 2], [4, 3, 8], [7, 5, 6]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 1, 6], [2, 5, 8], [3, 0, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 6, 1], [5, 4, 7], [2, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 5, 4], [1, 8, 7], [0, 3, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 2, 7], [5, 0, 6], [4, 1, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 2, 5], [7, 0, 6], [3, 8, 4]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[7, 1, 2], [0, 5, 3], [4, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[0, 3, 2], [6, 7, 8], [5, 1, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[2, 1, 8], [4, 3, 0], [6, 5, 7]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 3, 1], [7, 0, 8], [4, 5, 6]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 2, 7], [0, 5, 6], [4, 1, 8]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[2, 8, 7], [4, 1, 0], [6, 3, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 0], [8, 5, 6], [7, 3, 1]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[4, 2, 8], [3, 5, 1], [7, 0, 6]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[2, 3, 1], [7, 5, 8], [4, 0, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 2, 7], [4, 5, 6], [0, 1, 8]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[7, 0, 4], [5, 2, 6], [8, 3, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 7, 0], [6, 8, 1], [2, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 8, 0], [3, 2, 7], [1, 6, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 3, 2], [7, 4, 0], [5, 6, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 2, 6], [5, 0, 7], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 7, 6], [5, 0, 2], [8, 4, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 5, 2], [7, 0, 6], [3, 8, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 4, 7], [0, 5, 1], [8, 2, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 2, 4], [3, 5, 1], [8, 6, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 2, 6], [0, 5, 7], [4, 8, 1]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[7, 6, 1], [4, 2, 8], [5, 0, 3]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[4, 2, 1], [5, 8, 6], [0, 7, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[2, 8, 7], [4, 1, 6], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 3, 4], [6, 1, 2], [0, 7, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 2, 6], [4, 5, 7], [0, 8, 1]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[0, 3, 1], [2, 7, 8], [6, 4, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[8, 2, 1], [7, 0, 6], [4, 3, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 0, 1], [2, 7, 3], [4, 8, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[5, 3, 4], [6, 1, 2], [7, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 8, 2], [3, 4, 5], [7, 0, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 1, 0], [6, 2, 8], [3, 5, 4]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 1, 2], [3, 8, 5], [7, 0, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[2, 1, 0], [6, 7, 8], [4, 5, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 3, 4], [6, 1, 2], [7, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[3, 7, 2], [6, 5, 4], [1, 0, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 0, 2], [3, 8, 5], [7, 4, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 1, 2], [3, 0, 5], [7, 8, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[7, 2, 1], [6, 0, 3], [5, 8, 4]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[5, 4, 0], [2, 7, 1], [6, 3, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[3, 7, 2], [6, 5, 4], [1, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 2, 0], [3, 8, 5], [7, 4, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 1, 2], [3, 5, 0], [7, 8, 4]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[6, 2, 1], [3, 5, 0], [4, 8, 7]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[0, 5, 2], [4, 6, 8], [7, 1, 3]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 8, 4], [2, 7, 0], [3, 6, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[3, 6, 0], [7, 1, 2], [4, 5, 8]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 1, 6], [7, 3, 5], [8, 4, 2]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[5, 2, 0], [8, 4, 6], [3, 7, 1]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 4, 1], [7, 3, 8], [0, 2, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 4, 8], [1, 7, 2], [3, 6, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[4, 7, 8], [1, 6, 2], [0, 3, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 0, 6], [7, 3, 5], [8, 4, 2]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[7, 6, 2], [5, 1, 0], [3, 8, 4]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 4, 8], [2, 0, 5], [3, 7, 1]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[6, 1, 4], [3, 8, 7], [5, 2, 0]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[1, 2, 3], [0, 4, 6], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 21 and h(n): 3
# [[2, 0, 7], [4, 1, 6], [5, 8, 3]] is the best sub-puzzle to be solved with g(n): 19 and h(n): 5
# [[6, 0, 4], [7, 5, 1], [3, 2, 8]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[6, 4, 8], [2, 5, 0], [3, 7, 1]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 0, 5], [7, 8, 2], [4, 3, 6]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 2, 3], [4, 0, 6], [7, 5, 8]] is the best sub-puzzle to be solved with g(n): 22 and h(n): 2
# [[0, 2, 7], [4, 1, 6], [5, 8, 3]] is the best sub-puzzle to be solved with g(n): 20 and h(n): 4
# [[7, 6, 3], [5, 1, 2], [4, 8, 0]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 1, 8], [3, 4, 0], [7, 2, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[8, 0, 4], [7, 2, 6], [3, 1, 5]] is the best sub-puzzle to be solved with g(n): 17 and h(n): 7
# [[1, 2, 3], [4, 5, 6], [7, 0, 8]] is the best sub-puzzle to be solved with g(n): 23 and h(n): 1
# [[0, 2, 1], [5, 3, 4], [7, 6, 8]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[6, 4, 0], [2, 7, 8], [3, 1, 5]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[0, 7, 1], [8, 2, 5], [6, 4, 3]] is the best sub-puzzle to be solved with g(n): 16 and h(n): 8
# [[8, 2, 4], [7, 0, 6], [3, 1, 5]] is the best sub-puzzle to be solved with g(n): 18 and h(n): 6
# [[1, 2, 3], [4, 5, 6], [7, 8, 0]] is the best sub-puzzle to be solved with g(n): 24 and h(n): 0
# reached the goal state!
# the number of expansion required: 18775
# maximum queue size: 10199
# time required: 14.83009995599997

# %%
x_labels = ['0', '2', '4', '8', '12', '16', '20', '24']

UC = [0, 3, 18, 183, 1411, 8629, 29290, 71272]
MD = [0, 3, 6, 12, 28, 64, 231, 794]
MT = [0, 3, 6, 16, 90, 395, 1624, 10199]
# Plot the data
plt.plot(x_labels, UC, label='UC')
plt.plot(x_labels, MD, label='MD')
plt.plot(x_labels, MT, label='MT')

# Add labels and legend
plt.xlabel('Depth of puzzle')
plt.ylabel('Maximum queue size')
plt.title('Maximum queue size Vs. Depth of puzzle')
plt.legend()

# Display the plot
plt.show()
